# %%
import pandas as pd

# %%
data = pd.read_csv("IHME-GBD_2019_DATA-f4377959-1/IHME-GBD_2019_DATA-f4377959-1.csv")
data

unique_values_Yld = data['cause_name'].unique()
unique_values_Yld
# Out:
# array(['Sickle cell disorders',
#        'HIV/AIDS - Drug-susceptible Tuberculosis',
#        'Upper digestive system diseases',
#        'Chronic kidney disease due to diabetes mellitus type 1',
#        'Chronic kidney disease due to diabetes mellitus type 2',
#        'Communicable, maternal, neonatal, and nutritional diseases',
#        'Other non-communicable diseases', 'Vitamin A deficiency',
#        'Dietary iron deficiency', 'Uterine fibroids',
#        'Neglected tropical diseases and malaria', 'Malaria',
#        'HIV/AIDS resulting in other diseases', 'Thalassemias',
#        'G6PD deficiency', 'Other gynecological diseases',
#        'Hemoglobinopathies and hemolytic anemias', 'Thalassemias trait',
#        'All causes', 'Intestinal nematode infections', 'Hookworm disease',
#        'Chronic kidney disease due to other and unspecified causes',
#        'Other hemoglobinopathies and hemolytic anemias',
#        'Chronic kidney disease',
# ...

# %%
data_filtered = data[data['measure_name'] == 'Prevalence']
data_filtered
# Out:
# Empty DataFrame
# Columns: [measure_id, measure_name, location_id, location_name, sex_id, sex_name, age_id, age_name, cause_id, cause_name, rei_id, rei_name, metric_id, metric_name, year, val, upper, lower]
# Index: []

# %%
data2 = pd.read_csv("IHME-GBD_2019_DATA-f4377959-2/IHME-GBD_2019_DATA-f4377959-2.csv")

data2_filtered = data2[data2['measure_name'] == 'Prevalence']
data2_filtered
# Out:
#         measure_id measure_name  location_id location_name  sex_id sex_name  \
# 12856            5   Prevalence           43       Albania       3     Both
# 12857            5   Prevalence           43       Albania       3     Both
# 12858            5   Prevalence           43       Albania       3     Both
# 12859            5   Prevalence           43       Albania       3     Both
# 12860            5   Prevalence           43       Albania       3     Both
# ...            ...          ...          ...           ...     ...      ...
# 499995           5   Prevalence           92         Spain       3     Both
# 499996           5   Prevalence           92         Spain       3     Both
# 499997           5   Prevalence           92         Spain       3     Both
# 499998           5   Prevalence           92         Spain       3     Both
# 499999           5   Prevalence           92         Spain       3     Both
#
#         age_id  age_name  cause_id  \
# ...

# %%
data3 = pd.read_csv("IHME-GBD_2019_DATA-f4377959-3/IHME-GBD_2019_DATA-f4377959-3.csv")
data3

data3_filtered = data3[data3['measure_name'] == 'Prevalence']
data3_filtered
# Out:
#        measure_id measure_name  location_id location_name  sex_id sex_name  \
# 0               5   Prevalence           92         Spain       3     Both
# 1               5   Prevalence           92         Spain       3     Both
# 2               5   Prevalence           92         Spain       3     Both
# 3               5   Prevalence           92         Spain       3     Both
# 4               5   Prevalence           92         Spain       3     Both
# ...           ...          ...          ...           ...     ...      ...
# 25707           5   Prevalence          396    San Marino       3     Both
# 25708           5   Prevalence          396    San Marino       3     Both
# 25709           5   Prevalence          396    San Marino       3     Both
# 25710           5   Prevalence          396    San Marino       3     Both
# 25711           5   Prevalence          396    San Marino       3     Both
#
#        age_id  age_name  cause_id  \
# ...

# %%
full_prevalence_data = pd.concat([data2_filtered, data3_filtered], ignore_index=True)

# %%
unique_values = full_prevalence_data['cause_name'].unique()

# %%
unique_values
# Out:
# array(['Uterine fibroids', 'Other gynecological diseases',
#        'Other non-communicable diseases', 'Dietary iron deficiency',
#        'Malaria', 'Schistosomiasis', 'Other infectious diseases',
#        'Neglected tropical diseases and malaria',
#        'HIV/AIDS and sexually transmitted infections', 'All causes',
#        'Communicable, maternal, neonatal, and nutritional diseases',
#        'Chronic kidney disease due to other and unspecified causes',
#        'Gynecological diseases', 'Other unspecified infectious diseases',
#        'Non-communicable diseases',
#        'Other hemoglobinopathies and hemolytic anemias',
#        'Endocrine, metabolic, blood, and immune disorders',
#        'Diabetes and kidney diseases', 'Upper digestive system diseases',
#        'Maternal and neonatal disorders', 'Gastritis and duodenitis',
#        'Inflammatory bowel disease',
#        'HIV/AIDS - Drug-susceptible Tuberculosis',
# ...

# %%
#missing tuperculosis (maybe in the other category) --> just in relation with HIV
# cardiovescular


# we have Diabetes and kidney disease , chronic kidney due to diabetes type 1 and 2
#dietary we have
#kidney

# %%
unique_values = full_prevalence_data['rei_name'].unique()
print(unique_values)
# Out:
# ['Severe anemia' 'Anemia' 'Mild anemia' 'Moderate anemia'
#  'Mild hearing loss' 'Moderate hearing loss'
#  'Moderately severe hearing loss' 'Severe hearing loss' 'Blindness'
#  'Epilepsy' 'Moderate heart failure' 'Severe heart failure'
#  'Moderate intellectual disability' 'Severe intellectual disability'
#  'Moderate vision loss' 'Severe vision loss' 'Treated heart failure'
#  'Developmental intellectual disability' 'Blindness and vision loss'
#  'Primary infertility' 'Secondary infertility'
#  'Moderate pelvic inflammatory disease'
#  'Severe pelvic inflammatory disease' 'Guillain-Barré syndrome'
#  'Hearing loss' 'Heart failure' 'Infertility'
#  'Profound intellectual disability' 'Pelvic inflammatory disease'
#  'Treated epilepsy' 'Moderate epilepsy' 'Severe epilepsy'
#  'Mild heart failure' 'Profound hearing loss' 'Complete hearing loss'
#  'Mild intellectual disability' 'Presbyopia'
#  'Borderline intellectual disability']

# %%
filtered_prevalence_data = full_prevalence_data [(full_prevalence_data ['cause_name'] == 'Dietary iron deficiency') | (full_prevalence_data ['cause_name'] == 'Diabetes and kidney diseases') | (full_prevalence_data ['cause_name'] == 'Vitamin A deficiency')| (full_prevalence_data ['cause_name'] == 'Chronic kidney disease due to diabetes mellitus type 1') | (full_prevalence_data ["cause_name"] == 'Nutritional deficiencies') | (full_prevalence_data["cause_name"] =="Chronic kidney disease due to diabetes mellitus type 2") | (full_prevalence_data["cause_name"] == 'Chronic kidney disease due to hypertension')]

filtered_data = filtered_prevalence_data[filtered_prevalence_data['metric_name']== 'Number']

# %%
filtered_data
# Out:
#         measure_id measure_name  location_id location_name  sex_id sex_name  \
# 27               5   Prevalence           48       Hungary       3     Both
# 30               5   Prevalence           48       Hungary       3     Both
# 300              5   Prevalence           38      Mongolia       3     Both
# 303              5   Prevalence           38      Mongolia       3     Both
# 306              5   Prevalence           38      Mongolia       3     Both
# ...            ...          ...          ...           ...     ...      ...
# 512789           5   Prevalence          522         Sudan       3     Both
# 512804           5   Prevalence          396    San Marino       3     Both
# 512807           5   Prevalence          396    San Marino       3     Both
# 512810           5   Prevalence          396    San Marino       3     Both
# 512813           5   Prevalence          396    San Marino       3     Both
#
#         age_id  age_name  cause_id  \
# ...

# %%
unique_values = filtered_data['rei_name'].unique()

# %%
unique_values
# Out:
# array(['Moderate anemia', 'Severe anemia', 'Anemia',
#        'Blindness and vision loss', 'Mild anemia', 'Moderate vision loss',
#        'Severe vision loss', 'Blindness',
#        'Severe intellectual disability',
#        'Profound intellectual disability',
#        'Developmental intellectual disability'], dtype=object)

# %%
#new data

data = pd.read_csv("IHME-GBD_2019_DATA-64743d99-1/IHME-GBD_2019_DATA-64743d99-1.csv")

# %%
data
# Out:
#        measure_id                        measure_name  location_id  \
# 0               3  YLDs (Years Lived with Disability)            1
# 1               3  YLDs (Years Lived with Disability)            1
# 2               3  YLDs (Years Lived with Disability)            1
# 3               3  YLDs (Years Lived with Disability)            1
# 4               3  YLDs (Years Lived with Disability)            4
# ...           ...                                 ...          ...
# 58027           3  YLDs (Years Lived with Disability)        53621
# 58028           3  YLDs (Years Lived with Disability)        44889
# 58029           3  YLDs (Years Lived with Disability)        44889
# 58030           3  YLDs (Years Lived with Disability)        44869
# 58031           3  YLDs (Years Lived with Disability)        44869
#
#                                 location_name  sex_id sex_name  age_id  \
# 0                                      Global       3     Both      22
# ...

# %%
unique_values = data['cause_name'].unique()

# %%
unique_values
# Out:
# array(['All causes', 'Respiratory infections and tuberculosis',
#        'Diarrheal diseases', 'Lower respiratory infections'], dtype=object)

# %%
unique_values = data['rei_name'].unique()

unique_values
# Out:
# array(['Cholera', 'Campylobacter', 'H influenzae type B',
#        'Clostridium difficile', 'Enteropathogenic E coli',
#        'Cryptosporidium', 'Influenza', 'Shigella',
#        'Enterotoxigenic E coli', 'Rotavirus', 'Non-typhoidal Salmonella',
#        'Adenovirus', 'Entamoeba', 'Aeromonas', 'Meningococcal meningitis',
#        'Pneumococcus', 'Respiratory syncytial virus', 'Norovirus'],
#       dtype=object)

# %%
# respiratory and tuberculosis in this one


# still no cardiovascular disease

#diabtities just what i have in the first one

#respiratory either as cause or rei

#asthma still not found

#nutrional in the first sets

# %%
selection = data = data[(data['cause_name'] == 'Respiratory infections and tuberculosis') | (data['cause_name'] == 'Lower respiratory infections')]

# %%
test = selection['rei_name'].unique()
selection
# Out:
#        measure_id                        measure_name  location_id  \
# 4               3  YLDs (Years Lived with Disability)            4
# 5               3  YLDs (Years Lived with Disability)            4
# 30              3  YLDs (Years Lived with Disability)           20
# 31              3  YLDs (Years Lived with Disability)           20
# 64              3  YLDs (Years Lived with Disability)           13
# ...           ...                                 ...          ...
# 57967           3  YLDs (Years Lived with Disability)        60133
# 58016           3  YLDs (Years Lived with Disability)        44869
# 58017           3  YLDs (Years Lived with Disability)        44869
# 58030           3  YLDs (Years Lived with Disability)        44869
# 58031           3  YLDs (Years Lived with Disability)        44869
#
#                                 location_name  sex_id sex_name  age_id  \
# 4      Southeast Asia, East Asia, and Oceania       3     Both      22
# ...

# %%
full_data = pd.concat([selection, filtered_data], axis=0)

# %%
selected_data = full_data[['location_name', 'cause_name', 'rei_name', 'val', 'year']]
selected_data = selected_data[selected_data['year']== 2019]

# %%
selected_data
# Out:
#                                  location_name  \
# 5       Southeast Asia, East Asia, and Oceania
# 31                                    Viet Nam
# 65                                    Malaysia
# 73                                     Albania
# 81                                    Malaysia
# ...                                        ...
# 512789                                   Sudan
# 512804                              San Marino
# 512807                              San Marino
# 512810                              San Marino
# 512813                              San Marino
#
#                                                cause_name  \
# 5                 Respiratory infections and tuberculosis
# 31                Respiratory infections and tuberculosis
# 65                           Lower respiratory infections
# 73                Respiratory infections and tuberculosis
# 81                           Lower respiratory infections
# ...

# %%
pivot_table = pd.pivot_table(selected_data, values='val',  columns= ["cause_name"], index='location_name', dropna=True, aggfunc="sum")

# %%
pivot_table
# Out:
# cause_name     Chronic kidney disease due to diabetes mellitus type 1  \
# location_name
# Aceh                                                         NaN
# Acre                                                         NaN
# Addis Ababa                                                  NaN
# Afar                                                         NaN
# Afghanistan                                          8510.405452
# ...                                                          ...
# Zambia                                               4163.131483
# Zanjan                                                       NaN
# Zimbabwe                                             4673.495270
# Ōita                                                         NaN
# Ōsaka                                                        NaN
#
# cause_name     Chronic kidney disease due to diabetes mellitus type 2  \
# location_name
# Aceh                                                         NaN
# ...

# %%
threshold = 5  # Set the threshold to the number of non-NaN values you require
final_data = pivot_table.dropna()

# %%
final_data
# Out:
# cause_name                          Chronic kidney disease due to diabetes mellitus type 1  \
# location_name
# Afghanistan                                                               8510.405452
# Albania                                                                    753.182929
# Algeria                                                                  11842.162188
# American Samoa                                                               5.900786
# Andorra                                                                      8.421582
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                        3459.440715
# Viet Nam                                                                  8383.202862
# Yemen                                                                    10166.917052
# Zambia                                                                    4163.131483
# ...

# %%
final_data.to_csv('diseases.csv')
